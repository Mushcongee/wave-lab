# %%
import pandas as pd
df = pd.read_csv('/home/clarence/projects/wave-lab/data/metadata.csv')
df.head()
df.info()
df.describe()
df[df['label'] == 'chord']
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         10 non-null     str
#  1   frequencies  10 non-null     str
#  2   duration     10 non-null     float64
#  3   label        10 non-null     str
# dtypes: float64(1), str(3)
# memory usage: 452.0 bytes
#        name           frequencies  duration  label
# 2   C_major  261.63;329.63;392.00       2.0  chord
# 3   G_major  392.00;493.88;587.33       2.0  chord
# 5  Bb_major  466.16;587.33;698.46       2.0  chord
# 6   C_minor  261.63;311.13;392.00       2.0  chord
# 9  Ab_minor  415.30;493.88;622.25       2.0  chord

# %%
import sys; sys.path.append('..')
import matplotlib.pyplot as plt
from src.signals import generate_sine_wave
from src.report import build_feature_table

# %%
signal = generate_sine_wave(440, 0.01) # short snippet, easier to see
plt.plot(signal)
plt.title('440 Hz sine wave (10ms)')
plt.show()

# %%
# Cell 3 -- plot its FFT magnitude spectrum
# TODO: use np.fft.fft + np.fft.fftfreq like in features.py, plot magnitude vs frequency
import numpy as np
plt.plot(np.fft.fftfreq(len(signal), 1/48000), np.abs(np.fft.fft(signal)),)

# %%
# Cell 4 -- bar chart comparing average spectral_centroid: chord vs single_note
results = build_feature_table('/home/clarence/projects/wave-lab/data/metadata.csv')
results.groupby('label')['spectral_centroid'].mean().plot(kind='bar')
plt.title('Average spectral centroid by type')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 3
#       1 # Cell 4 -- bar chart comparing average spectral_centroid: chord vs single_note
#       2 import sys; sys.path.append('..')
# ----> 3 results = build_feature_table('../data/metadata.csv')
#       4 results.groupby('label')['spectral_centroid'].mean().plot(kind='bar')
#       5 plt.title('Average spectral centroid by type')
#       6 plt.show()
#
# File ~/projects/wave-lab/src/report.py:20, in build_feature_table(metadata_path)
#       5 """
#       6 For every row in metadata.csv: generate the signal (sine or chord depending on
#       7 how many frequencies are listed), compute rms/zcr/spectral_centroid, and collect
#    (...)     16 at the end -- much faster than appending to a DataFrame row by row.
#      17 """
#      18 # TODO: implement
#      19 # raise NotImplementedError
# ...
