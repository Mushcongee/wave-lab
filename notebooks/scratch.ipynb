# %%
import pandas as pd
df = pd.read_csv('/home/clarence/projects/wave-lab/data/metadata.csv')
df.head()
df.info()
df.describe()
df[df['label'] == 'chord']
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         10 non-null     str
#  1   frequencies  10 non-null     str
#  2   duration     10 non-null     float64
#  3   label        10 non-null     str
# dtypes: float64(1), str(3)
# memory usage: 452.0 bytes
#        name           frequencies  duration  label
# 2   C_major  261.63;329.63;392.00       2.0  chord
# 3   G_major  392.00;493.88;587.33       2.0  chord
# 5  Bb_major  466.16;587.33;698.46       2.0  chord
# 6   C_minor  261.63;311.13;392.00       2.0  chord
# 9  Ab_minor  415.30;493.88;622.25       2.0  chord

# %%
from src.report import build_feature_table

results = build_feature_table('data/metadata.csv')
results.groupby('label')[['rms', 'spectral_centroid']].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from src.report import build_feature_table
#       2
# ----> 3 results = build_feature_table('data/metadata.csv')
#       4 results.groupby('label')[['rms', 'spectral_centroid']].mean()
#
# File ~/projects/wave-lab/src/report.py:31, in build_feature_table(metadata_path)
#      29 else:
#      30     freqlist = row['frequencies'].split(';')
# ---> 31     signal = generate_chord(freqlist, row['duration'])
#      32 result_dict['rms'] = rms_energy(signal)
#      33 result_dict['zcr'] = zero_crossing_rate(signal)
#
# File ~/projects/wave-lab/src/signals.py:55, in generate_chord(frequencies, duration, sample_rate, amplitude)
#      53 chordarray = np.zeros(int(sample_rate * duration))
#      54 for i in frequencies:
# ---> 55     chordarray += generate_sine_wave(i, duration, sample_rate, amplitude)
# ...
